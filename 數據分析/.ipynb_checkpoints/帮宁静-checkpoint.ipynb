# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
sns.set()
plt.rcParams['font.sans-serif'] = ['SimHei'] # 显示中文标题 
plt.rcParams['axes.unicode_minus'] = False # 正常显示正负号

# %% [markdown]
# * 问题：1：在总表里筛选数据，接着创建唯一ID，最后把其他子表中总表没有的内容根据唯一ID拼接到总表后面
# * 过滤：空值过滤(删整行),ST(不景气的)过滤,范围过滤(筛选2.5~97.5%间的连续数据,避免极端影响)
# # 1.读数据

# %%
df1 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\roa.xlsx')
df2 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\独董比例.xlsx')
df3 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\固定资产.xlsx')
df4 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\营收增长率.xlsx')
df5 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\资产负债率.xlsx')
df6 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\总资产----同时也是班级的表，其他五个是年纪的表.xlsx')

# %%
df6.head()
# Out:
#     Stkcd      Reptdt Stknme Nindcd Nindnme   A001000000
# 0    证券代码      统计截止日期   证券简称   行业代码    行业名称          总资产
# 1  000004  2014-12-31   国农科技    C27   医药制造业  3.38283e+08
# 2  000004  2015-12-31   国农科技    C27   医药制造业  3.98674e+08
# 3  000004  2016-12-31   国农科技    C27   医药制造业  2.23716e+08
# 4  000004  2017-12-31   国农科技    C27   医药制造业  2.68844e+08

# %% [markdown]
# # 2.筛选12.31和A数据

# %%
def myfitter(col, ends, df):
    ###要过滤的列,过滤内容,df###
    return df[[t.endswith(ends) for t in df.iloc[:,col].values]]

# %%
df1 = myfitter(1,'12-31',df1)
df2 = myfitter(1,'12-31',df2)
df3 = myfitter(1,'12-31',df3)
df4 = myfitter(1,'12-31',df4)
df5 = myfitter(1,'12-31',df5)
df6 = myfitter(1,'12-31',df6)

df1 = myfitter(2,'A',df1)
df3 = myfitter(2,'A',df3)
df4 = myfitter(2,'A',df4)
df5 = myfitter(2,'A',df5)

# %% [markdown]
# # 3.ID生成

# %%
def createId(df,col1,col2):
    df['ID'] = df.iloc[:,col1]+df.iloc[:,col2]

# %%
createId(df1,0,1)
createId(df2,0,1)
createId(df3,0,1)
createId(df4,0,1)
createId(df5,0,1)
createId(df6,0,1)

# %% [markdown]
# # 4.合并表

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
print(df4.columns)
print(df5.columns)
print(df6.columns)
# Out:
# Index(['Stkcd', 'Accper', 'Typrep', 'F050203B', 'ID'], dtype='object')
# Index(['Stkcd', 'Reptdt', 'Stknme', 'dir', 'ID'], dtype='object')
# Index(['Stkcd', 'Accper', 'Typrep', 'C002006000', 'ID'], dtype='object')
# Index(['Stkcd', 'Accper', 'Typrep', 'F081701B', 'ID'], dtype='object')
# Index(['Stkcd', 'Accper', 'Typrep', 'F011201A', 'ID'], dtype='object')
# Index(['Stkcd', 'Reptdt', 'Stknme', 'Nindcd', 'Nindnme', 'A001000000', 'ID'], dtype='object')

# %%
# 创造空列
def createNoColList(df1,df2):
    colList = [str for str in df2.columns if str not in df1.columns]
    for str in colList:
        df1[str] = None

# %%
createNoColList(df6,df1)
createNoColList(df6,df2)
createNoColList(df6,df3)
createNoColList(df6,df4)
createNoColList(df6,df5)

# %%
df6.head()
# Out:
#     Stkcd      Reptdt Stknme Nindcd Nindnme   A001000000                ID  \
# 1  000004  2014-12-31   国农科技    C27   医药制造业  3.38283e+08  0000042014-12-31
# 2  000004  2015-12-31   国农科技    C27   医药制造业  3.98674e+08  0000042015-12-31
# 3  000004  2016-12-31   国农科技    C27   医药制造业  2.23716e+08  0000042016-12-31
# 4  000004  2017-12-31   国农科技    C27   医药制造业  2.68844e+08  0000042017-12-31
# 5  000004  2018-12-31   国农科技    C27   医药制造业  3.51177e+08  0000042018-12-31
#
#   Accper Typrep F050203B   dir C002006000 F081701B F011201A
# 1   None   None     None  None       None     None     None
# 2   None   None     None  None       None     None     None
# 3   None   None     None  None       None     None     None
# 4   None   None     None  None       None     None     None
# 5   None   None     None  None       None     None     None

# %% [markdown]
# * 根据ID筛选填充

# %%
df1.head()
# Out:
#         Stkcd      Accper Typrep  F050203B                ID
# 14889  002107  2014-12-31      A  0.055642  0021072014-12-31
# 14891  002538  2014-12-31      A  0.047583  0025382014-12-31
# 14893  002654  2014-12-31      A  0.044426  0026542014-12-31
# 14895  600593  2014-12-31      A   0.05516  6005932014-12-31
# 14897  300358  2014-12-31      A  0.124917  3003582014-12-31

# %%
# 把ID和索引做成字典方便检索
dt = dict(zip(df6['ID'].values,df6['ID'].index))

# %%
# 找出有ID的两个表的索引
def combineDf(df,df1):
    for idx in df1.index:
        id =df1.loc[idx,'ID']
        if id in dt:
            # print(idx)
            # 赋值
            for col in df1.columns:
                df.loc[dt[id],col] = df1.loc[idx,col]
    return df

# %%
df6 = combineDf(df6,df1)
df6 = combineDf(df6,df2)
df6 = combineDf(df6,df3)
df6 = combineDf(df6,df4)
df6 = combineDf(df6,df5)

# %%
# df6.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\中间表.xlsx')

# %% [markdown]
# # 5.空值过滤,ST过滤,范围过滤

# %%
# 空值过滤
# df6 = df6.dropna()

# %%
df6.head()
# Out:
#     Stkcd      Reptdt Stknme Nindcd Nindnme   A001000000                ID  \
# 1  000004  2014-12-31   国农科技    C27   医药制造业  3.38283e+08  0000042014-12-31
# 2  000004  2015-12-31   国农科技    C27   医药制造业  3.98674e+08  0000042015-12-31
# 3  000004  2016-12-31   国农科技    C27   医药制造业  2.23716e+08  0000042016-12-31
# 4  000004  2017-12-31   国农科技    C27   医药制造业  2.68844e+08  0000042017-12-31
# 5  000004  2018-12-31   国农科技    C27   医药制造业  3.51177e+08  0000042018-12-31
#
#        Accper Typrep  F050203B       dir   C002006000  F081701B  F011201A
# 1  2014-12-31      A  0.053838  0.333333     11212298  0.107499  0.534754
# 2  2015-12-31      A  0.018609  0.333333      4134756  0.494308  0.590402
# 3  2016-12-31      A  0.127625  0.333333  2.24494e+06   1.38821  0.203456
# 4  2017-12-31      A  0.023925  0.333333   5.8471e+06 -0.518178  0.315247
# 5  2018-12-31      A -0.069716  0.333333  1.75371e+07   1.64685  0.477966

# %%
# ST过滤
df6 = df6[[t.find('ST')==-1 for t in df6.iloc[:,2].values]]

# %%
# 范围过滤
def fitterMiAndMx(df,col,rate1,rate2):
    sortL = sorted(df[col].values)
    mi = sortL[int(len(sortL)*rate1)]
    mx = sortL[int(len(sortL)*rate2)]
    return df[[t>mi and t<mx for t in df.loc[:,col].values]]

# %%
#df6 = fitterMiAndMx(df6,'A001000000',0.025,0.975)
#df6 = fitterMiAndMx(df6,'F050203B',0.025,0.975)
#df6 = fitterMiAndMx(df6,'dir',0.025,0.975)
#df6 = fitterMiAndMx(df6,'C002006000',0.025,0.975)
#df6 = fitterMiAndMx(df6,'F081701B',0.025,0.975)
#df6 = fitterMiAndMx(df6,'F011201A',0.025,0.975)

# %%
# df6.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\完成表.xlsx')

# %% [markdown]
# # 二、分表处理(按年份分表,小表取最大值作为代表,其他删除)
# * 对分出来的6个表的每个企业取最近投资的行数据(称为最近增量表吧)

# %%
df7 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\产融集合(1).xlsx')

# %%
# 按年份分表
g = list(df7.groupby('year'))

# %%
df2013 = g[0][1]
df2014 = g[1][1]
df2015 = g[2][1]
df2016 = g[3][1]
df2017 = g[4][1]
df2018 = g[5][1]

# %%
# 取最大值作为代表,其他删除
def getMaxAndFitter(df,Name,col):
    dt = {}
    # 筛选企业最大值
    for name,val in zip(df.loc[:,Name].values,df.loc[:,col].values):
        if name not in dt:
            dt[name] = val
        else:
            dt[name] = max(dt[name],val)
    # 过滤
    return df[[val>=dt[name] for name,val in zip(df.loc[:,Name].values,df.loc[:,col].values)]]

# %%
df2013 = getMaxAndFitter(df2013,'名称','持有数量(万股/份)')
df2014 = getMaxAndFitter(df2014,'名称','持有数量(万股/份)')
df2015 = getMaxAndFitter(df2015,'名称','持有数量(万股/份)')
df2016 = getMaxAndFitter(df2016,'名称','持有数量(万股/份)')
df2017 = getMaxAndFitter(df2017,'名称','持有数量(万股/份)')
df2018 = getMaxAndFitter(df2018,'名称','持有数量(万股/份)')

df2013 = getMaxAndFitter(df2013,'名称','持股比例')
df2014 = getMaxAndFitter(df2014,'名称','持股比例')
df2015 = getMaxAndFitter(df2015,'名称','持股比例')
df2016 = getMaxAndFitter(df2016,'名称','持股比例')
df2017 = getMaxAndFitter(df2017,'名称','持股比例')
df2018 = getMaxAndFitter(df2018,'名称','持股比例')

# %%
df2015
# Out:
#             代码    名称   金融机构简称 金融机构类型    持有数量(万股/份)     持股比例          投资金额  \
# 278  000690.SZ  宝新能源   广东南粤银行     银行  69978.003000  11.2500  9.540452e+08
# 281  600167.SH  联美控股     国任财险     保险  18000.000000   6.0000  2.340000e+08
# 282  600200.SH  江苏吴中     江苏银行     银行   5191.088500   0.5000  3.602859e+07
# 283  600261.SH  阳光照明     长城证券     证券   1700.000000   0.6100  1.020000e+08
# 285  600293.SH  三峡新材     湖北银行     银行   1089.805100   0.5800  1.479600e+07
# 286  600331.SH  宏达股份     四川信托     信托  55401.280565  22.1605  2.470000e+08
# 287  600352.SH  浙江龙盛     锦州银行     银行      0.000000   0.0000  2.000000e+08
# 288  600518.SH  ST康美     广发基金   基金公司   1200.000000   9.4580  7.656000e+07
# 289  600693.SH  东百集团   福建海峡银行     银行    537.154300   0.1700  1.034800e+06
# 290  600738.SH  兰州民百     兰州银行     银行   5260.380000   1.0300  5.950000e+07
# 292  600873.SH  梅花生物     西藏银行     银行  12800.000000   4.2414  1.570000e+08
# 294  601011.SH   宝泰隆     龙江银行     银行      0.000000   0.3463  8.000000e+06
# 295  601155.SH  新城控股     苏州银行     银行   3000.000000   1.0000  1.560000e+08
# 296  603001.SH  奥康国际   温州民商银行     银行      0.000000   9.9000  1.980000e+08
# 297  603077.SH  和邦生物  乐山市商业银行     银行   5678.897000   3.1200  3.000000e+07
# 298  603968.SH  醋化股份     江苏银行     银行      0.000000   0.0000  2.230000e+06
#
#              期末余额       截止日期  year
# 278  9.540452e+08 2015-12-31  2015
# 281  2.340000e+08 2015-12-31  2015
# 282  3.602859e+07 2015-12-31  2015
# 283  9.645769e+07 2015-12-31  2015
# 285  1.479600e+07 2015-12-31  2015
# 286  1.400418e+09 2015-12-31  2015
# 287  0.000000e+00 2015-12-31  2015
# 288  3.971281e+08 2015-12-31  2015
# 289  4.449640e+06 2015-12-31  2015
# 290  1.160821e+08 2015-12-31  2015
# 292  1.570000e+08 2015-12-31  2015
# 294  1.636332e+07 2015-12-31  2015
# 295  1.700000e+08 2015-12-31  2015
# 296  0.000000e+00 2015-12-31  2015
# 297  0.000000e+00 2015-12-31  2015
# 298  2.230000e+06 2015-12-31  2015

# %% [markdown]
# * 最近增量表:把本年的数据依次合并到上一年即可

# %%
def insertAndCombine(df,df1,Name):
    lastDf = df1.copy()
    print("前:",lastDf.shape)
    dt = dict(zip(df[Name].values,df[Name].index))
    lastDt = dict(zip(lastDf[Name].values,lastDf[Name].index))
    # 本年,上年
    addDf = DataFrame()
    for name in df.loc[:,Name]:
        # print(name)
        if name in lastDf[Name].values:
            # 上年有,替换
            lastDf.loc[lastDt[name]] = df.loc[dt[name]]
        else:
            # 追加
            lastDf.append(df.loc[dt[name]])
            print(name,lastDf.shape)
            #print(df.loc[dt[name]])
    #print(addDf)
    #print(lastDf)
    #return pd.concat([lastDf,addDf])
    print('变化后',lastDf.shape)
    return lastDf

# %%
d2014 = insertAndCombine(df2014,df2013,'名称')
df2015 = insertAndCombine(df2015,df2014,'名称')
#df2016 = insertAndCombine(df2016,df2015,'名称')
#df2017 = insertAndCombine(df2017,df2016,'名称')
#df2018 = insertAndCombine(df2018,df2017,'名称')
# Out:
# (186, 10)
# (186, 10)
# (13, 10)
# (13, 10)

# %%
df2014
# Out:
#             代码    名称    金融机构简称 金融机构类型   持有数量(万股/份)     持股比例          投资金额  \
# 256  000159.SZ  国际实业    乌鲁木齐银行     银行    766.76390   0.2600  1.686881e+07
# 257  000301.SZ  东方盛虹  江苏苏州农商银行     银行   1239.76120   1.2400  5.000000e+06
# 262  000333.SZ  美的集团     顺德农商行     银行  32887.41600   9.4000  1.263774e+09
# 265  000426.SZ  兴业矿业      中诚信托     信托   4000.00000   1.6300  6.441481e+07
# 266  000513.SZ  丽珠集团    珠海华润银行     银行   8493.60000   1.5065  9.532576e+07
# 269  000516.SZ  国际医学    广东华兴银行     银行  12000.00000   2.4000  1.560000e+08
# 270  000540.SZ  中天金融      贵州银行     银行   7100.00000   0.9900  9.443000e+07
# 272  000559.SZ  万向钱潮      万向财务     财务  24000.00000  17.8300  2.400000e+08
# 273  000593.SZ  大通燃气      中铁信托     信托    453.79592   0.2300  4.980000e+06
# 274  000603.SZ  盛达资源      兰州银行     银行   5000.00000   1.3800  1.260000e+08
# 275  000615.SZ  京汉股份      湖北银行     银行   1766.74390   0.7900  1.584000e+07
# 276  000620.SZ   新华联      长沙银行     银行  14908.33090   5.7000  3.230165e+08
# 277  000626.SZ  远大控股    宁波东海银行     银行   9831.31700   9.6600  1.685500e+07
#
#              期末余额       截止日期  year
# 256  1.686881e+07 2014-12-31  2014
# 257  5.000000e+06 2014-12-31  2014
# 262  1.263774e+09 2014-12-31  2014
# 265  6.441481e+07 2014-12-31  2014
# 266  7.532576e+07 2014-12-31  2014
# 269  1.560000e+08 2014-12-31  2014
# 270  9.443000e+07 2014-12-31  2014
# 272  2.968820e+08 2014-12-31  2014
# 273  4.341650e+06 2014-12-31  2014
# 274  1.260000e+08 2014-12-31  2014
# 275  1.584000e+07 2014-12-31  2014
# 276  7.982358e+08 2014-12-31  2014
# 277  8.042203e+07 2014-12-31  2014

# %%
t = df2014.iloc[1,:]

# %%
t.index
# Out:
# Index(['代码', '名称', '金融机构简称', '金融机构类型', '持有数量(万股/份)', '持股比例', '投资金额', '期末余额',
#        '截止日期', 'year'],
#       dtype='object')

# %%
print(t)
t1 = DataFrame()
t1.column = t.index
t1.append(t)
print(t1)
# Out:
# 代码                      000301.SZ
# 名称                           东方盛虹
# 金融机构简称                   江苏苏州农商银行
# 金融机构类型                         银行
# 持有数量(万股/份)                1239.76
# 持股比例                         1.24
# 投资金额                        5e+06
# 期末余额                        5e+06
# 截止日期          2014-12-31 00:00:00
# year                         2014
# Name: 2, dtype: object
# Empty DataFrame
# Columns: []
# Index: []
# C:\Users\WuChuPeng\data_for_wuchupeng\software_install\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2018.append(t)
# Out:
#             代码    名称       金融机构简称 金融机构类型    持有数量(万股/份)     持股比例          投资金额  \
# 328  600293.SH  三峡新材         湖北银行     银行   1089.805100   0.5800  1.479600e+07
# 329  600331.SH  宏达股份         四川信托     信托  77561.780565  22.1605  2.470000e+08
# 330  600439.SH   瑞贝卡         中原银行     银行  10912.559800   0.0000  0.000000e+00
# 331  600496.SH  精工钢构         瑞丰银行     银行      0.000000   4.1600  3.230000e+08
# 238  1.350108e+08 2013-12-31  2013
# 239  1.652895e+08 2013-12-31  2013
# 240  4.000000e+06 2018-12-31  2018
# 242  5.366728e+07 2013-12-31  2013
# 243  1.233027e+09 2018-12-31  2018
# 244  3.000000e+07 2013-12-31  2013
# 245  1.636332e+07 2015-12-31  2015
# 247  9.127504e+07 2013-12-31  2013
# 250  1.000000e+08 2013-12-31  2013
# 251  1.000000e+07 2013-12-31  2013
# 252  0.000000e+00 2018-12-31  2018
# 253  1.000000e+05 2013-12-31  2013
# 254  1.000000e+06 2013-12-31  2013
#
# [186 rows x 10 columns]

# %%
#df2013.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2013.xlsx')
#df2014.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2014.xlsx')
#df2015.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2015.xlsx')
#df2016.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2016.xlsx')
#df2017.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2017.xlsx')
#df2018.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\2018.xlsx')

# %%
print(df2013.shape,df2014.shape,df2015.shape,df2016.shape,df2017.shape,df2018.shape)
# Out:
# (186, 10) (186, 10) (186, 10) (186, 10) (186, 10) (186, 10)

# %% [markdown]
# # 6个小表的持股占比合并到另一个表里
# * 年份修改同一修改

# %%
# 指定第一列为索引
df6 = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\完成表.xlsx',index_col=0)

# %%
# 去掉.SZ
def removeSt(str):
    return str[0:-3]

# %%
df2013['代码'] = df2013['代码'].apply(removeSt)
df2014['代码'] = df2014['代码'].apply(removeSt)
df2015['代码'] = df2015['代码'].apply(removeSt)
df2016['代码'] = df2016['代码'].apply(removeSt)
df2017['代码'] = df2017['代码'].apply(removeSt)
df2018['代码'] = df2018['代码'].apply(removeSt)

# %%
# 修改年份
df2013['year'] = '2013-12-31'
df2014['year'] = '2014-12-31'
df2015['year'] = '2015-12-31'
df2016['year'] = '2016-12-31'
df2017['year'] = '2017-12-31'
df2018['year'] = '2018-12-31'

# %%
# ID生成
def createId(df,col1,col2):
    df['ID'] = df.loc[:,col1]+df.loc[:,col2]

# %%
createId(df2013,'代码','year')
createId(df2014,'代码','year')
createId(df2015,'代码','year')
createId(df2016,'代码','year')
createId(df2017,'代码','year')
createId(df2018,'代码','year')

# %%
# 合并持股比例到总表
df6['持股比例'] = None
# 把ID和索引做成字典方便检索
dt = dict(zip(df6['ID'].values,df6['ID'].index))

# %%
# 找出有ID的两个表的索引
ttt = 0
def combineDfRate(df,df1,colName):
    for idx in df1.index:
        id =df1.loc[idx,'ID']
        if id in dt:
            print(id)
            global ttt
            ttt+=1
            df.loc[dt[id],colName] = df1.loc[idx,colName]
    return df

# %%
df6 = combineDfRate(df6,df2013,'持股比例')
df6 = combineDfRate(df6,df2014,'持股比例')
df6 = combineDfRate(df6,df2015,'持股比例')
df6 = combineDfRate(df6,df2016,'持股比例')
df6 = combineDfRate(df6,df2017,'持股比例')
df6 = combineDfRate(df6,df2018,'持股比例')
# Out:
# 0003012014-12-31
# 0005132014-12-31
# 0005162014-12-31
# 0007002014-12-31
# 0007962014-12-31
# 0008212014-12-31
# 0009972014-12-31
# 0020122014-12-31
# 0020422014-12-31
lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# ~\data_for_wuchupeng\software_install\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     662                            freeze_panes=freeze_panes)
#     663         if need_save:
# --> 664             writer.save()
#
# ~\data_for_wuchupeng\software_install\anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1950         """
#    1951
# -> 1952         return self.book.close()
#    1953
#    1954     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# ~\data_for_wuchupeng\software_install\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     302         if not self.fileclosed:
#     303             self.fileclosed = 1
# --> 304             self._store_workbook()
#     305
#     306     def set_size(self, width, height):
#
# ~\data_for_wuchupeng\software_install\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     650
#     651         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 652                             allowZip64=self.allow_zip64)
#     653
#     654         # Add XML sub-files to the Zip file with their Excel filename.
#
# ~\data_for_wuchupeng\software_install\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1202             while True:
#    1203                 try:
# -> 1204                     self.fp = io.open(file, filemode)
#    1205                 except OSError:
#    1206                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\WuChuPeng\\Desktop\\其他\\宁静\\汇总表持股比例未删减版.xlsx'

# %%
dfidx = pd.read_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\编号(1).xlsx')

# %%
stocks = np.append(dfidx.iloc[:,0].values,301)

# %%
df6.head()
# Out:
#     Stkcd      Reptdt Stknme Nindcd               Nindnme    A001000000  \
# 10      5  2018-12-31   世纪星源    N77            生态保护和环境治理业  3.121423e+09
# 16      8  2014-12-31    宝利来    H61                   住宿业  6.740280e+08
# 18      8  2016-12-31   神州高铁    C37  铁路、船舶、航空航天和其它运输设备制造业  8.192657e+09
# 19      8  2017-12-31   神州高铁    C37  铁路、船舶、航空航天和其它运输设备制造业  1.067832e+10
# 21      9  2014-12-31   中国宝安    S90                    综合  1.472550e+10
#
#                   ID      Accper Typrep  F050203B       dir    C002006000  \
# 10  0000052018-12-31  2018-12-31      A  0.051959  0.357143  1.679095e+07
# 16  0000082014-12-31  2014-12-31      A  0.011942  0.428571  2.851638e+06
# 18  0000082016-12-31  2016-12-31      A  0.090060  0.428571  6.028932e+07
# 19  0000082017-12-31  2017-12-31      A  0.094283  0.428571  5.718175e+07
# 21  0000092014-12-31  2014-12-31      A  0.033352  0.428571  6.434760e+08
#
#     F081701B  F011201A  持股比例
# 10 -0.084271  0.494040  None
# 16  0.008977  0.112276  None
# 18  0.448569  0.246583  None
# 19  0.242497  0.326949  None
# 21  0.037654  0.628934  None

# %%
# 索引过滤
newDf = df6[[t in stocks for t in df6.iloc[:,0].values]]

# %%
newDf.to_excel(r'C:\Users\WuChuPeng\Desktop\其他\宁静\汇总表持股比例96未删减版.xlsx')
