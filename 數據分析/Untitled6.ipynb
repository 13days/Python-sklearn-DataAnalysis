# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_clipboard()

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df = df.pivot(index='month', columns='year',values='passengers')

# %%
df
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# September   136   158   184   209   237   259   312   355   404   404   463
#
# year       1960
# month
# April       461
# August      606
# December    432
# February    391
# January     417
# July        622
# June        535
# March       419
# May         472
# November    390
# October     461
# September   508

# %%
sns.heatmap(df)

# %%
df.plot()

# %%
sns.heatmap(df, annot=True)

# %%
sns.heatmap(df, annot=True, fmt='d')

# %%
s = df.sum()
s
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# dtype: int64

# %%
sns.barplot(x=s.index, y=s.values)

# %%
s.plot(kind='bar')

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x2214dc04ac8>,
#  <matplotlib.lines.Line2D at 0x2214dc392b0>,
#  <matplotlib.lines.Line2D at 0x2214dc39400>,
#  <matplotlib.lines.Line2D at 0x2214dc39550>,
#  <matplotlib.lines.Line2D at 0x2214dc396a0>,
#  <matplotlib.lines.Line2D at 0x2214dc397f0>,
#  <matplotlib.lines.Line2D at 0x2214dc39940>,
#  <matplotlib.lines.Line2D at 0x2214dc39a90>,
#  <matplotlib.lines.Line2D at 0x2214dc39be0>,
#  <matplotlib.lines.Line2D at 0x2214dc39d30>,
#  <matplotlib.lines.Line2D at 0x2214dc17278>,
#  <matplotlib.lines.Line2D at 0x2214dc39f98>]

# %%
df.plot()
